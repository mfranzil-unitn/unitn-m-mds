# %% [markdown]
# #Import Models

# %%
import cv2
import dlib
import numpy as np
import glob
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
from keras.models import load_model

# %%
# !pip install git+https://github.com/giuliano-oliveira/gdown_folder.git
import gdown
gdown.download_folder('https://drive.google.com/drive/u/1/folders/11yJEd2cue34lSodhoKUzOHNbbn31sXWh', quiet=True)
# Out:
# Collecting git+https://github.com/giuliano-oliveira/gdown_folder.git
#   Cloning https://github.com/giuliano-oliveira/gdown_folder.git to /tmp/pip-req-build-m3ue6xli
#   Running command git clone -q https://github.com/giuliano-oliveira/gdown_folder.git /tmp/pip-req-build-m3ue6xli
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown==3.12.2) (3.4.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from gdown==3.12.2) (0.16.0)
# Collecting pathlib2
#   Downloading pathlib2-2.3.6-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown==3.12.2) (4.6.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown==3.12.2) (1.15.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown==3.12.2) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown==3.12.2) (4.62.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown==3.12.2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown==3.12.2) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown==3.12.2) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown==3.12.2) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown==3.12.2) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-3.12.2-py3-none-any.whl size=12126 sha256=9fd1fa2dd0bb4c8eefcdee45b0486db4512c44fefc36fbd97f418b8c3f1550d0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-h2qu8y2g/wheels/da/5e/24/24fbdc00f3e6e91cefe494b31d53de8b91241ef924a15358dc
# Successfully built gdown
# Installing collected packages: pathlib2, gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# Successfully installed gdown-3.12.2 pathlib2-2.3.6
# '/content/MARCON_FF++social/val.json'

# %% [markdown]
# # Import  test video

# %%
# !gdown https://drive.google.com/uc?id=18tLnSThjqsxDs1sPl-vLt9VwqK3yp63i
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18tLnSThjqsxDs1sPl-vLt9VwqK3yp63i
# To: /content/000_003.mp4
# 100% 465k/465k [00:00<00:00, 16.3MB/s]

# %%
# from github FaceForensics++
def get_boundingbox(face, width, height, scale=1.3):  # takes a dlib face to return a bounding box
   x1 = face.left()
   y1 = face.top()
   x2 = face.right()
   y2 = face.bottom()

   size_bb = int(max(x2 - x1, y2 - y1)*scale)   # size of bounding box 

   center_x = (x1 + x2)/2
   center_y = (y1 + y2)/2
   
   x1 = max(int(center_x - size_bb // 2), 0)
   y1 = max(int(center_y - size_bb // 2), 0)
   size_bb = min(width - x1, size_bb)
   size_bb = min(height - y1, size_bb)
   
   return x1, y1, size_bb

def preprocess_input(cropped_frame):
  img = Image.fromarray(cropped_frame)
  img = img.resize([299,299], Image.NEAREST)
  img = np.asarray(img)
  img = img / 255.0
  img = np.expand_dims(img, axis=0)
  return img

# analyze the whole video
def analyze_video(video_dir, model):
   cap = cv2.VideoCapture(video_dir)
      
   count = 0  # count frames read
   numb = int(cap.get(cv2.CAP_PROP_FRAME_COUNT) )   # get number of frames
   prediction = []
   
   pbar = tqdm(total=numb-count, position=0, leave=True, desc='Analyzing video: ')   

   while (cap.isOpened() ):
     ret, frame = cap.read()
     pbar.update(1)

     if not ret:
        break
     
     height, width = frame.shape[:2]

     face_detector = dlib.get_frontal_face_detector()  # set face detector model
     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # convert to grayscale
     faces = face_detector(gray, 1)    # detect faces
       
     if len(faces):    # select first largest face
       face = faces[0]  
       x, y, size = get_boundingbox(face, width, height)   # get bounding box
       cropped_face = frame[y:y+size, x:x+size]    # crop face
       preprocessed_input = preprocess_input(cropped_face)  #preprocess for feeding network
       prediction.append(model.predict(preprocessed_input)[0])
     else:
       cap.set(1,count+1)       
     
     count+=1

     if (count >= numb):  #stop when all frames are processed
       break
       pbar.close()
       cap.release()
       cv2.destroyAllWindows()
  
   return np.asarray(prediction)

def decode_prediction(prediction):
  class_names = ['real', 'fake'] 
  for i, logits in enumerate(prediction):
    class_idx = tf.argmax(logits).numpy()
    p = logits[class_idx]
    name = class_names[class_idx]
    print("Frame {} prediction: {} ({:4.1f}%)".format(i, name, 100*p))

# %%
## ANALYZE VIDEO (eg. video manipulated with NeuralTextures)
# load model
model = load_model('MARCON_FF++social/Models/Xception/Xception_NeuralTextures.h5')

predictions = analyze_video('000_003.mp4', model)
decode_prediction(predictions)
# Out:
# Analyzing video: 100%|██████████| 396/396 [05:56<00:00,  1.11it/s]
# Frame 0 prediction: real (91.0%)
# Frame 1 prediction: real (84.9%)
# Frame 2 prediction: real (86.9%)
# Frame 3 prediction: real (91.1%)
# Frame 4 prediction: real (91.7%)
# Frame 5 prediction: real (90.4%)
# Frame 6 prediction: real (90.4%)
# Frame 7 prediction: real (92.8%)
# Frame 8 prediction: real (94.1%)
# Frame 9 prediction: real (88.5%)
# Frame 10 prediction: real (91.3%)
# Frame 11 prediction: real (77.6%)
# Frame 12 prediction: real (69.2%)
# Frame 13 prediction: fake (80.1%)
# Frame 14 prediction: fake (96.8%)
# Frame 15 prediction: fake (97.8%)
# Frame 16 prediction: real (53.9%)
# Frame 17 prediction: fake (73.8%)
# Frame 18 prediction: fake (82.0%)
# Frame 19 prediction: fake (72.9%)
# Frame 20 prediction: fake (81.7%)
# Frame 21 prediction: fake (90.1%)
# Frame 22 prediction: fake (75.5%)
# Frame 23 prediction: fake (99.7%)
# Frame 24 prediction: fake (98.4%)
# Frame 25 prediction: real (90.6%)
# Frame 26 prediction: real (50.8%)
# Frame 27 prediction: fake (94.6%)
# Frame 28 prediction: fake (87.8%)
# Frame 29 prediction: real (99.5%)
# Frame 30 prediction: fake (98.4%)
# Frame 31 prediction: fake (79.6%)
# Frame 32 prediction: real (81.8%)
# Frame 33 prediction: fake (100.0%)
# Frame 34 prediction: fake (100.0%)
# Frame 35 prediction: fake (71.1%)
# Frame 36 prediction: fake (86.4%)
# Frame 37 prediction: fake (97.5%)
# Frame 38 prediction: real (96.1%)
# Frame 39 prediction: fake (97.7%)
# Frame 40 prediction: fake (85.3%)
# Frame 41 prediction: fake (100.0%)
# Frame 42 prediction: fake (99.9%)
# Frame 43 prediction: fake (100.0%)
# Frame 44 prediction: fake (93.6%)
# Frame 45 prediction: fake (88.9%)
# Frame 46 prediction: fake (51.4%)
# Frame 47 prediction: fake (88.3%)
# Frame 48 prediction: real (51.2%)
# Frame 49 prediction: fake (76.2%)
# Frame 50 prediction: real (75.7%)
# Frame 51 prediction: real (99.8%)
# Frame 52 prediction: real (99.4%)
# Frame 53 prediction: real (53.7%)
# Frame 54 prediction: real (66.8%)
# Frame 55 prediction: fake (97.7%)
# Frame 56 prediction: fake (88.8%)
# Frame 57 prediction: fake (93.5%)
# Frame 58 prediction: fake (76.5%)
# Frame 59 prediction: fake (91.3%)
# Frame 60 prediction: real (66.1%)
# Frame 61 prediction: fake (93.2%)
# Frame 62 prediction: real (68.6%)
# Frame 63 prediction: real (92.6%)
# Frame 64 prediction: real (82.4%)
# Frame 65 prediction: real (82.3%)
# Frame 66 prediction: real (77.9%)
# Frame 67 prediction: real (72.3%)
# Frame 68 prediction: real (61.7%)
# Frame 69 prediction: real (65.6%)
# Frame 70 prediction: real (96.5%)
# Frame 71 prediction: fake (54.8%)
# Frame 72 prediction: real (91.8%)
# Frame 73 prediction: real (94.5%)
# Frame 74 prediction: real (96.5%)
# Frame 75 prediction: real (75.0%)
# Frame 76 prediction: real (90.7%)
# Frame 77 prediction: fake (63.9%)
# Frame 78 prediction: real (90.2%)
# Frame 79 prediction: fake (58.4%)
# Frame 80 prediction: real (94.1%)
# Frame 81 prediction: fake (53.9%)
# Frame 82 prediction: real (80.6%)
# Frame 83 prediction: fake (78.8%)
# Frame 84 prediction: fake (87.2%)
# Frame 85 prediction: fake (54.9%)
# Frame 86 prediction: fake (97.8%)
# Frame 87 prediction: fake (98.9%)
# Frame 88 prediction: real (76.4%)
# Frame 89 prediction: real (62.5%)
# Frame 90 prediction: fake (85.5%)
# Frame 91 prediction: real (58.7%)
# Frame 92 prediction: fake (92.7%)
# Frame 93 prediction: real (97.5%)
# Frame 94 prediction: fake (67.3%)
# Frame 95 prediction: fake (60.3%)
# Frame 96 prediction: fake (79.5%)
# Frame 97 prediction: real (82.8%)
# Frame 98 prediction: real (53.9%)
# Frame 99 prediction: fake (89.9%)
# Frame 100 prediction: real (96.5%)
# Frame 101 prediction: real (84.6%)
# Frame 102 prediction: real (98.7%)
# Frame 103 prediction: real (92.8%)
# Frame 104 prediction: real (99.2%)
# Frame 105 prediction: real (92.4%)
# Frame 106 prediction: real (97.2%)
# Frame 107 prediction: real (88.0%)
# Frame 108 prediction: real (99.7%)
# Frame 109 prediction: real (98.6%)
# Frame 110 prediction: real (98.9%)
# Frame 111 prediction: real (97.5%)
# Frame 112 prediction: real (95.9%)
# Frame 113 prediction: real (97.4%)
# Frame 114 prediction: real (96.8%)
# Frame 115 prediction: real (94.8%)
# Frame 116 prediction: real (98.4%)
# Frame 117 prediction: real (95.3%)
# Frame 118 prediction: real (95.9%)
# Frame 119 prediction: real (96.8%)
# Frame 120 prediction: real (98.2%)
# Frame 121 prediction: real (69.4%)
# Frame 122 prediction: real (80.1%)
# Frame 123 prediction: real (95.5%)
# Frame 124 prediction: real (98.1%)
# Frame 125 prediction: real (69.6%)
# Frame 126 prediction: real (95.3%)
# Frame 127 prediction: real (61.0%)
# Frame 128 prediction: real (76.8%)
# Frame 129 prediction: fake (55.3%)
# Frame 130 prediction: real (99.1%)
# Frame 131 prediction: fake (63.9%)
# Frame 132 prediction: real (97.6%)
# Frame 133 prediction: real (90.2%)
# Frame 134 prediction: real (99.0%)
# Frame 135 prediction: real (85.8%)
# Frame 136 prediction: real (86.7%)
# Frame 137 prediction: fake (68.4%)
# Frame 138 prediction: fake (55.3%)
# Frame 139 prediction: fake (61.2%)
# Frame 140 prediction: fake (86.9%)
# Frame 141 prediction: fake (96.2%)
# Frame 142 prediction: fake (98.9%)
# Frame 143 prediction: fake (64.5%)
# Frame 144 prediction: fake (99.4%)
# Frame 145 prediction: fake (90.0%)
# Frame 146 prediction: fake (92.7%)
# Frame 147 prediction: fake (58.9%)
# Frame 148 prediction: fake (87.3%)
# Frame 149 prediction: real (91.2%)
# Frame 150 prediction: fake (98.5%)
# Frame 151 prediction: fake (98.3%)
# Frame 152 prediction: fake (96.8%)
# Frame 153 prediction: fake (67.9%)
# Frame 154 prediction: fake (95.8%)
# Frame 155 prediction: real (87.7%)
# Frame 156 prediction: fake (88.4%)
# Frame 157 prediction: fake (75.9%)
# Frame 158 prediction: fake (89.6%)
# Frame 159 prediction: fake (98.2%)
# Frame 160 prediction: fake (55.9%)
# Frame 161 prediction: fake (99.7%)
# Frame 162 prediction: fake (77.4%)
# Frame 163 prediction: fake (59.0%)
# Frame 164 prediction: real (91.7%)
# Frame 165 prediction: fake (83.4%)
# Frame 166 prediction: fake (89.1%)
# Frame 167 prediction: fake (97.0%)
# Frame 168 prediction: fake (96.0%)
# Frame 169 prediction: fake (98.0%)
# Frame 170 prediction: fake (79.7%)
# Frame 171 prediction: fake (90.5%)
# Frame 172 prediction: fake (74.2%)
# Frame 173 prediction: fake (96.5%)
# Frame 174 prediction: real (91.3%)
# Frame 175 prediction: fake (86.6%)
# Frame 176 prediction: fake (60.6%)
# Frame 177 prediction: fake (88.1%)
# Frame 178 prediction: real (58.7%)
# Frame 179 prediction: fake (74.4%)
# Frame 180 prediction: real (83.7%)
# Frame 181 prediction: fake (84.7%)
# Frame 182 prediction: fake (75.9%)
# Frame 183 prediction: fake (96.6%)
# Frame 184 prediction: real (86.0%)
# Frame 185 prediction: fake (58.1%)
# Frame 186 prediction: real (81.4%)
# Frame 187 prediction: real (99.7%)
# Frame 188 prediction: real (96.8%)
# Frame 189 prediction: real (99.5%)
# Frame 190 prediction: real (65.1%)
# Frame 191 prediction: real (99.8%)
# Frame 192 prediction: real (86.0%)
# Frame 193 prediction: real (96.0%)
# Frame 194 prediction: real (68.9%)
# Frame 195 prediction: real (99.9%)
# Frame 196 prediction: real (78.8%)
# Frame 197 prediction: fake (96.8%)
# Frame 198 prediction: fake (94.4%)
# Frame 199 prediction: real (54.1%)
# Frame 200 prediction: real (97.4%)
# Frame 201 prediction: fake (92.9%)
# Frame 202 prediction: real (94.5%)
# Frame 203 prediction: fake (99.6%)
# Frame 204 prediction: real (81.3%)
# Frame 205 prediction: fake (73.7%)
# Frame 206 prediction: real (99.5%)
# Frame 207 prediction: fake (56.0%)
# Frame 208 prediction: fake (64.3%)
# Frame 209 prediction: real (72.5%)
# Frame 210 prediction: real (94.7%)
# Frame 211 prediction: real (55.9%)
# Frame 212 prediction: fake (82.4%)
# Frame 213 prediction: real (99.5%)
# Frame 214 prediction: fake (78.8%)
# Frame 215 prediction: fake (97.7%)
# Frame 216 prediction: fake (99.9%)
# Frame 217 prediction: fake (97.1%)
# Frame 218 prediction: fake (100.0%)
# Frame 219 prediction: fake (79.8%)
# Frame 220 prediction: fake (77.0%)
# Frame 221 prediction: real (76.4%)
# Frame 222 prediction: real (93.2%)
# Frame 223 prediction: fake (92.7%)
# Frame 224 prediction: real (98.5%)
# Frame 225 prediction: fake (99.3%)
# Frame 226 prediction: real (54.8%)
# Frame 227 prediction: fake (99.9%)
# Frame 228 prediction: fake (98.7%)
# Frame 229 prediction: fake (99.9%)
# Frame 230 prediction: real (92.1%)
# Frame 231 prediction: fake (94.3%)
# Frame 232 prediction: fake (86.6%)
# Frame 233 prediction: real (57.3%)
# Frame 234 prediction: real (98.5%)
# Frame 235 prediction: real (55.9%)
# Frame 236 prediction: real (54.5%)
# Frame 237 prediction: fake (87.1%)
# Frame 238 prediction: real (91.2%)
# Frame 239 prediction: real (77.9%)
# Frame 240 prediction: real (98.9%)
# Frame 241 prediction: real (98.4%)
# Frame 242 prediction: real (91.9%)
# Frame 243 prediction: real (88.1%)
# Frame 244 prediction: real (99.5%)
# Frame 245 prediction: fake (66.1%)
# Frame 246 prediction: real (93.9%)
# Frame 247 prediction: real (62.1%)
# Frame 248 prediction: real (96.2%)
# Frame 249 prediction: fake (70.3%)
# Frame 250 prediction: real (99.2%)
# Frame 251 prediction: fake (69.4%)
# Frame 252 prediction: real (97.6%)
# Frame 253 prediction: fake (78.5%)
# Frame 254 prediction: real (63.1%)
# Frame 255 prediction: fake (62.3%)
# Frame 256 prediction: fake (69.3%)
# Frame 257 prediction: fake (98.4%)
# Frame 258 prediction: fake (97.1%)
# Frame 259 prediction: fake (99.8%)
# Frame 260 prediction: fake (98.3%)
# Frame 261 prediction: fake (98.7%)
# Frame 262 prediction: real (65.0%)
# Frame 263 prediction: real (74.3%)
# Frame 264 prediction: real (92.7%)
# Frame 265 prediction: real (92.6%)
# Frame 266 prediction: real (77.4%)
# Frame 267 prediction: fake (92.9%)
# Frame 268 prediction: fake (57.3%)
# Frame 269 prediction: real (81.9%)
# Frame 270 prediction: real (62.8%)
# Frame 271 prediction: real (91.9%)
# Frame 272 prediction: fake (96.4%)
# Frame 273 prediction: real (51.8%)
# Frame 274 prediction: fake (97.9%)
# Frame 275 prediction: fake (99.6%)
# Frame 276 prediction: fake (53.9%)
# Frame 277 prediction: fake (58.3%)
# Frame 278 prediction: fake (94.5%)
# Frame 279 prediction: fake (65.5%)
# Frame 280 prediction: fake (97.3%)
# Frame 281 prediction: fake (98.7%)
# Frame 282 prediction: fake (92.8%)
# Frame 283 prediction: fake (86.8%)
# Frame 284 prediction: fake (67.8%)
# Frame 285 prediction: fake (91.3%)
# Frame 286 prediction: real (84.2%)
# Frame 287 prediction: real (95.3%)
# Frame 288 prediction: fake (95.3%)
# Frame 289 prediction: fake (99.7%)
# Frame 290 prediction: real (73.2%)
# Frame 291 prediction: fake (99.6%)
# Frame 292 prediction: real (82.8%)
# Frame 293 prediction: fake (67.8%)
# Frame 294 prediction: fake (77.3%)
# Frame 295 prediction: fake (85.7%)
# Frame 296 prediction: fake (67.3%)
# Frame 297 prediction: real (83.7%)
# Frame 298 prediction: fake (67.3%)
# Frame 299 prediction: real (51.0%)
# Frame 300 prediction: real (59.0%)
# Frame 301 prediction: fake (70.9%)
# Frame 302 prediction: fake (96.3%)
# Frame 303 prediction: fake (98.9%)
# Frame 304 prediction: fake (52.3%)
# Frame 305 prediction: fake (61.6%)
# Frame 306 prediction: fake (91.9%)
# Frame 307 prediction: fake (99.6%)
# Frame 308 prediction: real (95.9%)
# Frame 309 prediction: real (80.1%)
# Frame 310 prediction: real (100.0%)
# Frame 311 prediction: fake (58.5%)
# Frame 312 prediction: real (98.1%)
# Frame 313 prediction: real (90.4%)
# Frame 314 prediction: real (99.7%)
# Frame 315 prediction: fake (67.7%)
# Frame 316 prediction: real (97.8%)
# Frame 317 prediction: real (88.5%)
# Frame 318 prediction: real (99.9%)
# Frame 319 prediction: real (89.8%)
# Frame 320 prediction: real (96.7%)
# Frame 321 prediction: real (99.0%)
# Frame 322 prediction: real (98.1%)
# Frame 323 prediction: real (98.3%)
# Frame 324 prediction: real (52.0%)
# Frame 325 prediction: real (93.9%)
# Frame 326 prediction: real (97.9%)
# Frame 327 prediction: real (97.1%)
# Frame 328 prediction: real (85.3%)
# Frame 329 prediction: real (91.4%)
# Frame 330 prediction: real (91.2%)
# Frame 331 prediction: real (94.9%)
# Frame 332 prediction: real (92.4%)
# Frame 333 prediction: real (90.0%)
# Frame 334 prediction: fake (72.4%)
# Frame 335 prediction: fake (83.6%)
# Frame 336 prediction: fake (65.7%)
# Frame 337 prediction: real (92.9%)
# Frame 338 prediction: real (100.0%)
# Frame 339 prediction: real (97.7%)
# Frame 340 prediction: real (75.2%)
# Frame 341 prediction: real (98.0%)
# Frame 342 prediction: real (53.5%)
# Frame 343 prediction: real (93.0%)
# Frame 344 prediction: real (76.6%)
# Frame 345 prediction: real (99.6%)
# Frame 346 prediction: real (99.8%)
# Frame 347 prediction: real (99.4%)
# Frame 348 prediction: real (51.2%)
# Frame 349 prediction: real (100.0%)
# Frame 350 prediction: real (66.2%)
# Frame 351 prediction: real (96.4%)
# Frame 352 prediction: real (100.0%)
# Frame 353 prediction: real (100.0%)
# Frame 354 prediction: fake (98.4%)
# Frame 355 prediction: real (90.7%)
# Frame 356 prediction: fake (100.0%)
# Frame 357 prediction: fake (95.7%)
# Frame 358 prediction: fake (99.9%)
# Frame 359 prediction: real (51.2%)
# Frame 360 prediction: fake (98.4%)
# Frame 361 prediction: fake (99.1%)
# Frame 362 prediction: fake (99.7%)
# Frame 363 prediction: fake (73.3%)
# Frame 364 prediction: fake (98.6%)
# Frame 365 prediction: real (87.4%)
# Frame 366 prediction: real (67.7%)
# Frame 367 prediction: real (73.7%)
# Frame 368 prediction: fake (97.2%)
# Frame 369 prediction: fake (96.9%)
# Frame 370 prediction: fake (88.2%)
# Frame 371 prediction: fake (67.0%)
# Frame 372 prediction: fake (96.8%)
# Frame 373 prediction: real (99.7%)
# Frame 374 prediction: fake (68.3%)
# Frame 375 prediction: real (88.8%)
# Frame 376 prediction: fake (67.2%)
# Frame 377 prediction: real (76.8%)
# Frame 378 prediction: fake (95.9%)
# Frame 379 prediction: fake (99.9%)
# Frame 380 prediction: real (79.9%)
# Frame 381 prediction: fake (98.4%)
# Frame 382 prediction: fake (99.7%)
# Frame 383 prediction: fake (95.3%)
# Frame 384 prediction: fake (89.8%)
# Frame 385 prediction: fake (92.9%)
# Frame 386 prediction: fake (56.4%)
# Frame 387 prediction: fake (82.3%)
# Frame 388 prediction: fake (75.1%)
# Frame 389 prediction: fake (96.8%)
# Frame 390 prediction: real (58.1%)
# Frame 391 prediction: fake (62.4%)
# Frame 392 prediction: fake (96.3%)
# Frame 393 prediction: fake (93.9%)
# Frame 394 prediction: fake (90.5%)
# Frame 395 prediction: fake (64.5%)

# %% [markdown]
# #Exercise
# Using the dataset, check the drop of perfomance when a model trained on non-shared videos is used on shared ones. Then check the opposite. \\
# How could we improve the results?
# You can find the models in 'MARCON_FF++social/Models/*/ . The models marked with 'YT' underwent transfer learning on Youtube shared videos. In contrast, the models marked with 'FB'underwent transferlearning on Facebook share videos.

# %%
# !gdown https://drive.google.com/uc?id=13bzOI4iRMCnYgrPzZG8jaH0vhl92kY6D
# !unzip video_fake_face_detection.zip

# %%
#YOUR CODE#
